# %%
# CF notes:  before handing off for students check for the following:
    # SOLUTION - means I left my solution so let's remove that
    # WIP - means I have an idea, but execution or relevance not all figured out yet

# ALSO - add context to the README in the repo for students, or in folder??  not sure...

# %% [markdown]
# # Welcome to the Data Manipulation Lesson.
#
# In this lesson, we will be using this workbook in tandum with the reading assignments.
#
# The workbook has been broken up into sections.  Each section has an article for you to read, be presented with a few questions to check your understanding, and code for you to work with related to the reading topics.
#
# Note: The dataset you will be using with each exercise is not the dataset in the article.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from  scipy import stats

data= pd.read_csv("titanic.csv")


# import all the things here

# %% [markdown]
# ## Before You Get Started
#
# We are going to be using the Titanic Dataset. Make sure to run a head() before you start working with manipulation methods.

# %%
# Run the head of your data set here:
#data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
# check for duplicates
data.duplicated().sum()  #SOLUTION
# Out:
# 107

# %%
# if there are, go ahead and drop them
data.drop_duplicates()    #SOLUTION
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# While the columns not the "prettiest", don't adjust any of them just yet.  
# We are going to update some and add some as we workthrough this notebook.
# Applologies for the extra visual "noise" on your screen.
# You will be given the option to tidy up the columns at the end of this notebook.

# %% [markdown]
# ## Note:  If your tables don't appear to have accepted your changes, try the "Run All" option in the "Cell" section of the menu bar.

# %% [markdown]
# # A. Aggregation
#
# 1. Please read the following:
#     - [Python | Pandas dataframe.aggregate()](https://www.geeksforgeeks.org/python-pandas-dataframe-aggregate/)
#     - [Python | Pandas dataframe.groupby()](https://www.geeksforgeeks.org/python-pandas-dataframe-groupby/)
# 1. Answer the Check Your Understanding Questions
# 1. Work through the section Exercises

# %% [markdown]
# ### Check Your Understanding:
#
# Using the titanic dataset
#
# 1. What is the syntax for multiple aggregation functions acrosss a single column, such as 'age'?
#     - **data.agg({"age":["sum", "mean"]})**
#     -
#
# 1. What data type is the syntax using?
#     - dictionary
#     -
# 1. What is this line of doing with the data? **data_group = data.groupby("embark_town")**
#     - grouping by the town embarked
#     -
#
# 1.  What is this line of data doing? **data_group = data.groupby("embark_town").agg("mean")**
#     - grouping the mean only of the other columns based on embarkment

# %% [markdown]
# # TODO:
#
# ### 1. Add prompt to try groupby().describe() combo
# ### 2. Edits

# %%
# 1. Using the titanic data set, groupby "embark_town".

# 1a. Create a variable that will represent the grouping of data.
# 1b. Intitalize it using the groupby() function and pass it the column.
data_group = data.groupby("embark_town")   #SOLUTION

# To view the grouped data as a table, use the variable_name.first()
data_group.first() #SOLUTION
# Out:
#              survived  pclass     sex   age  sibsp  parch     fare embarked  \
# embark_town
# Cherbourg           1       1  female  38.0      1      0  71.2833        C
# Queenstown          0       3    male   2.0      0      0   8.4583        Q
# Southampton         0       3    male  22.0      1      0   7.2500        S
#
#              class    who  adult_male deck alive  alone
# embark_town
# Cherbourg    First  woman       False    C   yes  False
# Queenstown   Third    man        True    C    no   True
# Southampton  Third    man        True    C    no  False

# %%
# SOLUTION

data_group1 = data.groupby("survived").describe()
data_group1
# Out:
#          pclass                                                 age  \
#           count      mean       std  min  25%  50%  75%  max  count
# survived
# 0         549.0  2.531876  0.735805  1.0  2.0  3.0  3.0  3.0  424.0
# 1         342.0  1.950292  0.863321  1.0  1.0  2.0  3.0  3.0  290.0
#
#                      ... parch        fare                             \
#                mean  ...   75%  max  count       mean        std  min
# survived             ...
# 0         30.626179  ...   0.0  6.0  549.0  22.117887  31.388207  0.0
# 1         28.343690  ...   1.0  5.0  342.0  48.395408  66.596998  0.0
#
#
#               25%   50%   75%       max
# survived
# 0          7.8542  10.5  26.0  263.0000
# 1         12.4750  26.0  57.0  512.3292
#
# [2 rows x 40 columns]

# %%
# Using your variable, method chain head() and agg().  
# Pass one of the following statistical values to agg: 
    # 'sum', 'mean', 'median', 'min', 'max', 'std', 'var', 'first', 'last':
    
data_group.head().agg("mean")    #SOLUTION


#Things to Think about:
# How does the data look when you pass "sum" vs when you pass "mean" to agg()?
#Note:  agg() and aggregate() are identical
# Out:
# survived       0.588235
# pclass         2.235294
# age           31.750000
# sibsp          0.470588
# parch          0.058824
# fare          28.997300
# adult_male     0.352941
# alone          0.705882
# dtype: float64

# %%
# 2. Next, apply aggregation across muliple columns using dictionary functionality.

# ---- Notes on Dictionaries. ----
# A dictionary is a Python collection type.  

age_dictionary={"age":["sum", "max"]}
    
    #It has a single key, "age", and a list of values, "sum", and "max".
    #This structure is called "Key-Value-Pair" and is how you can organize and manipulate dictionary objects.
        # dictionary_name = {key:[values]}
            # keys and values can be any data type, but must use correct data type syntax 
    #Like lists, dictionaries are mutable.

    #In this example we are going to make a new variable, "dictionary_group", 
        #and set it equal to our aggreated dataset.
    #We passed our dictionary object to agg().  
    #The values here, reflect the aggregation operations we want to preform on the age column.

dictionary_agg=data.agg(age_dictionary)
dictionary_agg

# ---- End of Note ----
# Out:
#           age
# sum  21205.17
# max     80.00

# %%
# 2a. What if we want to look at more than one column at a time?  We pass more dictionaries to the agg function.

# Create a variable to hold at least 3 columns. 
    #Aggregate the following:  col 1: "sum" & "count"; col 2: "std" & "min", and col 3: "count" & "sum"
    

    
#SOLUTION - see article 1 for syntax

# %%
#Groupby and Basic Math

# %%
# 3.  Let's now add Groupby to our Aggregation.
# Let's group by the 'pclass'.  Create a variable to hold your grouped data, like we did in question 1.

#passenger_class=

passenger_class = data.groupby(['pclass'])  #SOLUTION

#passenger_class.first() #<-- use first() here instead of head()

# %%
#4. We want to do muliple aggregation functions to our newly grouped data set
# We created a variable to hold a list of functions from the agg function.
agg_func_list = ['sum', 'mean', 'median', 'min', 'max', 'std', 'var', 'first', 'last', 'count']

#Apply the agg function to our passenger_class variable.  Then pass our list to the function.
passenger_class.agg(agg_func_list)   #SOLUTION
# Out:
#        survived                                                                \
#             sum      mean median min max       std       var first last count
# pclass
# 1           136  0.629630      1   0   1  0.484026  0.234281     1    1   216
# 2            87  0.472826      0   0   1  0.500623  0.250624     1    0   184
# 3           119  0.242363      0   0   1  0.428949  0.183998     0    0   491
#
#         ... alone                                                           \
#         ...   sum      mean median    min   max       std       var  first
# pclass  ...
# 1       ...   109  0.504630   True  False  True  0.501140  0.251141  False
# 2       ...   104  0.565217   True  False  True  0.497081  0.247090  False
# 3       ...   324  0.659878   True  False  True  0.474233  0.224897  False
#
#
#         last count
# pclass
# 1       True   216
# 2       True   184
# 3       True   491
#
# [3 rows x 70 columns]

# %%
# 5.  Using only a list provides us with the entire table.  What if we only want to look at age vs pclass?  
# We can create a variable to hold a dictionary for the age column.  the Key would be "age" and the values are the functions from the agg function.
# It would look like this:
agg_func_dict = {
    'age':
    ['sum', 'mean', 'median', 'min', 'max', 'std', 'var', 'first', 'last', 'count']
}
passenger_class.agg(agg_func_dict)  #SOLUTION

# 5a.  Looking at this syntax, create a dictionary variable for the "survived" column and pass it to passenger_class.agg():
# Code it here:



#SOLUTION ---
# agg_func_dict = {
#     'survived':
#     ['sum', 'mean', 'median', 'min', 'max', 'std', 'var', 'first', 'last', 'count']
# }
# passenger_class.agg(agg_func_dict)
# Out:
#             age                                                             \
#             sum       mean median   min   max        std         var first
# pclass
# 1       7111.42  38.233441   37.0  0.92  80.0  14.802856  219.124543  38.0
# 2       5168.83  29.877630   29.0  0.67  70.0  14.001077  196.030152  14.0
# 3       8924.92  25.140620   24.0  0.42  74.0  12.495398  156.134976  22.0
#
#
#         last count
# pclass
# 1       26.0   186
# 2       27.0   173
# 3       32.0   355

# %%
# AGG WITH TEXT ------------- tier 3
# agg_func_dict = {
#     'deck':
#     [stats.mode, set]
# }
# passenger_class.agg(agg_func_dict)

# %% [markdown]
# # B. Recoding and Creating New Values and Variables
#
# Reading:
# 1. [How to create new columns derived from existing columns?](https://pandas.pydata.org/docs/getting_started/intro_tutorials/05_add_columns.html)
# 1.[Recode Data](https://pythonfordatascienceorg.wordpress.com/recode-data/)
#
# Suggested Reading:
# - [How to manipulate textual data?](https://pandas.pydata.org/docs/getting_started/intro_tutorials/10_text_data.html)

# %% [markdown]
# # TODO:
#
# ### 1. Edits

# %% [markdown]
# ### Check Your Understanding
#
# 1. T/F: When updating a column with the following syntax, you need a loop to iterate through each value.
#     1. **F**
# 1. What is the syntax to rename a column?
#     1. **renamed_data = data_name.rename(columns={"original_name": "new_name","original_name": "new_name"}**
# 1. Converting numeric data to catergorical data is an example of?
#     1. Recoding

# %%
### Plans for this section

#1.  convert fare prices then to an estimate of today (in pounds)
    # converseion resource: https://www.in2013dollars.com/uk/inflation/1912?amount=1
#2. Use function to recode series data (reading # 2) 
#3. Create new column of age groups (reading # 2) and 2 diff plots

# %%
# As questions arrise during your data exploring and cleaning, you might want to test them out.  
# In this instance, we want to make sure the values we want to manipulate remain untouched. 
# One thing we can do is to add a new column that will contain our manipulations.

# 1. Create a new column by manipulating the values of different column.
# Specifically, create a new column that allows us to compare the cost of fare in pounds back in 1912 to 2021.
# This website can help you find the 2021 fare amount:  https://www.in2013dollars.com/uk/inflation/1912

data["fare_2021"] = (data["fare"] * 117.17)  #SOLUTION

# %%
# 2. Renaming values

# So far, all data about sex is a string or bool.  
# There are ways to work with categorical data values, but for right now, let's convert one into 0 for male, and 1 for female.

# %%
# 1. Work with rename()
# We used this same method with the pumpkin data set.
#data["who"] = data["who"].replace({"man":0, "woman":1})         # SOLUTION

# %%
# 2. We can also use functions to update values.

# Using the syntax in the "Recode Data" article from the reading list, create a function "set_sex_to_number" that 
# retuns a value of 0 if the value represents a male or 1 if the value represents a female.

def set_sex_to_number(series):
    if series == "man":
        return 0
    else:
        return 1
    
data["who"] = data["who"].apply(set_sex_to_number) # SOLUTION

# %%
# Check your output:
data.tail()   #SOLUTION
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#      who  adult_male deck  embark_town alive  alone  fare_2021
# 886    0        True  NaN  Southampton    no   True  1523.2100
# 887    1       False    B  Southampton   yes   True  3515.1000
# 888    1       False  NaN  Southampton    no  False  2747.6365
# 889    0        True    C    Cherbourg   yes   True  3515.1000
# 890    0        True  NaN   Queenstown    no   True   908.0675

# %%
#SOLUTION
# 3. Create new column to check age groups

def age_groups(series):
    if series <20:
        return "0-19 years"
    elif 20 <= series < 30:
        return "20-29"
    elif 30 <= series < 40:
        return "30-39 years"
    elif 40 <= series < 50:
        return "40-49"
    elif 50 <= series < 60:
        return "50-59"
    elif 60 <= series < 70:
        return "60-69"
    elif 70 <= series < 80:
        return "70-79"
    else:
        return "no data"
    
data["age_group"] = data["age"].apply(age_groups)  #SOLUTION

# Use this new column in the pivot/melt section

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  who  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third    0
# 1         1       1  female  38.0      1      0  71.2833        C  First    1
# 2         1       3  female  26.0      0      0   7.9250        S  Third    1
# 3         1       1  female  35.0      1      0  53.1000        S  First    1
# 4         0       3    male  35.0      0      0   8.0500        S  Third    0
#
#    adult_male deck  embark_town alive  alone    fare_2021    age_group
# 0        True  NaN  Southampton    no  False   849.482500        20-29
# 1       False    C    Cherbourg   yes  False  8352.264261  30-39 years
# 2       False  NaN  Southampton   yes   True   928.572250        20-29
# 3       False    C  Southampton   yes  False  6221.727000  30-39 years
# 4        True  NaN  Southampton    no   True   943.218500  30-39 years

# %%
data.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#      who  adult_male deck  embark_town alive  alone  fare_2021    age_group
# 886    0        True  NaN  Southampton    no   True  1523.2100        20-29
# 887    1       False    B  Southampton   yes   True  3515.1000   0-19 years
# 888    1       False  NaN  Southampton    no  False  2747.6365      no data
# 889    0        True    C    Cherbourg   yes   True  3515.1000        20-29
# 890    0        True  NaN   Queenstown    no   True   908.0675  30-39 years

# %% [markdown]
# # C. Reshaping Tables
#
# Reading:
# 1. [How to reshape the layout of tables?](https://pandas.pydata.org/docs/getting_started/intro_tutorials/07_reshape_table_layout.html)
#
# Suggested Reading:
# 1. [pandas.pivot_table](https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html)
# 1. [pandas.melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html)
# 1. [pandas.pivot](https://pandas.pydata.org/docs/reference/api/pandas.pivot.html)

# %% [markdown]
# # TODO:
# ### 1. Add a sort_values example
# ### 2. Demo pivot vs pivot_tables
# ### 3. Edits

# %% [markdown]
# ### Check Your Understanding:
#
# 1.  T/F: pivot() only allows you to perform aggertations to the table.
#     1. **F**
# 1. Which method do you use to create a "Wide-to-Long" table?
#     1. **melt()**
# 1. T/F: When creating a small table, you should store it in its own variable to keep your original table safe.
#     1. **T**

# %%
# 1. pivot the table of the summed data where the values are "who", index is "pclass" and "deck", and the columns are "age_group"
data_pt = data.pivot_table("who", ["pclass", "age_group"], "survived", aggfunc = np.sum) #SOLUTION
data_pt
# SOLUTION
# Out:
# survived               0     1
# pclass age_group
# 1      0-19 years    1.0  16.0
#        20-29         1.0  15.0
#        30-39 years   0.0  27.0
#        40-49         0.0  13.0
#        50-59         1.0  11.0
#        60-69         0.0   3.0
#        70-79         0.0   NaN
#        no data       0.0   9.0
# 2      0-19 years    0.0  25.0
#        20-29         3.0  22.0
#        30-39 years   1.0  16.0
#        40-49         1.0   9.0
#        50-59         1.0   5.0
#        60-69         0.0   0.0
#        70-79         0.0   NaN
#        no data       0.0   2.0
# 3      0-19 years   40.0  33.0
#        20-29        16.0  15.0
#        30-39 years   9.0   7.0
#        40-49         9.0   0.0
#        50-59         0.0   NaN
#        60-69         0.0   1.0
#        70-79         0.0   NaN
#        no data      17.0  25.0

# %%
# 2. pivot the table of the summed data where the values are "who", index is "pclass" and "deck", and the columns are "age_group"
data_pt1 = data.pivot_table("survived", ["fare", "fare_2021"], "age_group", aggfunc = np.sum) #SOLUTION
data_pt1
# SOLUTION
# Out:
# age_group              0-19 years  20-29  30-39 years  40-49  50-59  60-69  \
# fare     fare_2021
# 0.0000   0.000000             0.0    1.0          0.0    0.0    NaN    NaN
# 4.0125   470.144625           NaN    0.0          NaN    NaN    NaN    NaN
# 5.0000   585.850000           NaN    NaN          0.0    NaN    NaN    NaN
# 6.2375   730.847875           NaN    NaN          NaN    NaN    NaN    0.0
# 6.4375   754.281875           NaN    NaN          0.0    NaN    NaN    NaN
# ...                           ...    ...          ...    ...    ...    ...
# 227.5250 26659.104250         1.0    NaN          1.0    1.0    NaN    NaN
# 247.5208 29002.012136         NaN    0.0          NaN    NaN    1.0    NaN
# 262.3750 30742.478750         1.0    1.0          NaN    NaN    NaN    NaN
# 263.0000 30815.710000         0.0    2.0          NaN    NaN    NaN    0.0
# 512.3292 60029.612364         NaN    NaN          3.0    NaN    NaN    NaN
#
# age_group              70-79  no data
# ...

# %%
# 3. Wide to Long

wide_long = data.pivot(columns="sex", values="pclass")
wide_long

# Question - how does this table differ from data_pt in the box above?
    #Specifically, how is pclass different?  
    # SOLUTION
# Out:
# sex  female  male
# 0       NaN   3.0
# 1       1.0   NaN
# 2       3.0   NaN
# 3       1.0   NaN
# 4       NaN   3.0
# ..      ...   ...
# 886     NaN   2.0
# 887     1.0   NaN
# 888     3.0   NaN
# 889     NaN   1.0
# 890     NaN   3.0
#
# [891 rows x 2 columns]

# %%
# 4. melt a table
data_melt = pd.melt(data, id_vars=["embarked"], value_vars=["fare", "deck"])
data_melt
# SOLUTION
# Out:
#      embarked variable    value
# 0           S     fare     7.25
# 1           C     fare  71.2833
# 2           S     fare    7.925
# 3           S     fare     53.1
# 4           S     fare     8.05
# ...       ...      ...      ...
# 1777        S     deck      NaN
# 1778        S     deck        B
# 1779        S     deck      NaN
# 1780        C     deck        C
# 1781        Q     deck      NaN
#
# [1782 rows x 3 columns]

# %%
# default melt
data_m=pd.melt(data)
data_m
# SOLUTION
# Out:
#         variable        value
# 0       survived            0
# 1       survived            1
# 2       survived            1
# 3       survived            1
# 4       survived            0
# ...          ...          ...
# 15142  age_group        20-29
# 15143  age_group   0-19 years
# 15144  age_group      no data
# 15145  age_group        20-29
# 15146  age_group  30-39 years
#
# [15147 rows x 2 columns]

# %%
# WIP
# Compare data_melt and data_m
# 0r ask about the organization of the table

# %% [markdown]
# # D. Merge/Join & Append

# %% [markdown]
# # TODO:
#
# ## create reading and directions -- using pet data set
# ### Needs context, too.
#
#
# ## Check Your Understanding

# %%
#THIS WILL BE FOR THE MERGE/JOIN Section for the moment -------------------------


#merging two datasets side by side
df1 = pd.DataFrame({'Name':['Willow','Alyce','Steve','Hazel', 'Ivan', 'Beatrice', 'Skeeter', 'Bruce', 'BunBun','Alex','Behr', 'Rocket', 'Peanut'],
                      'ID':['22','34','77','35', '12','89', '21','76','45','32','11','09','01'],
                 'Species':['Dog','Cat','Cat','Rat', 'Rat', 'Cat', 'Cat', 'Horse','Rabbit', 'Dog', 'Dog', 'Dog', 'Dog'],
                    'Age':[6, 17, 14, 2, 2, 12, 18, 37, 5, 13, 9, 4, 2 ]})
df2 = pd.DataFrame({'Rabies_Status':["True", "True", "True","","","True", "False", "True","","False", "False", "True", "True" ],
                    'Last_Visit':[2021, 2021, 2021, 2020, 2018, 2021, 2017, 2021, 2004, 2009, 2021, 2021, 2021  ],
                  'Clinic_ID':['22','34','77','35', '12','89', '21','76','45','32','11','09','01']})
df = pd.merge(df1,df2, left_on = 'ID', right_on='Clinic_ID',validate='m:1', how='inner', indicator=True)
df
#once you've merged your dataset you are free to drop one of the repeated columns as long as they are similar
#df.drop('Clinic_ID', axis=1)
# Out:
#         Name  ID Species  Age Rabies_Status  Last_Visit Clinic_ID _merge
# 0     Willow  22     Dog    6          True        2021        22   both
# 1      Alyce  34     Cat   17          True        2021        34   both
# 2      Steve  77     Cat   14          True        2021        77   both
# 3      Hazel  35     Rat    2                      2020        35   both
# 4       Ivan  12     Rat    2                      2018        12   both
# 5   Beatrice  89     Cat   12          True        2021        89   both
# 6    Skeeter  21     Cat   18         False        2017        21   both
# 7      Bruce  76   Horse   37          True        2021        76   both
# 8     BunBun  45  Rabbit    5                      2004        45   both
# 9       Alex  32     Dog   13         False        2009        32   both
# 10      Behr  11     Dog    9         False        2021        11   both
# 11    Rocket  09     Dog    4          True        2021        09   both
# ...
